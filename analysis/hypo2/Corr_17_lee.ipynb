# %%
import FinanceDataReader as fdr
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)

# %%
stock_dict = {
    '삼호개발': '010960',
    '이화공영': '001840',
    '홈센타홀딩스': '060560',
    '특수건설': '026150',
    '동신건설': '025950',
    #'mohenz': '006920',
    # 'aprogen': '007460'
    }
stock_dict
# Out:
# {'삼호개발': '010960',
#  '이화공영': '001840',
#  '홈센타홀딩스': '060560',
#  '특수건설': '026150',
#  '동신건설': '025950'}

# %%
# 선거 이전:  "2006-08-20", "2007-04-22"

list_01 = []
for item_code in stock_dict.values():
    close_1 = fdr.DataReader(item_code, "2006-08-20", "2007-04-22")['Close']
    list_01.append(close_1)

mb_01 = pd.concat(list_01, axis=1)
mb_01.columns = stock_dict.keys()
mb_01.reset_index(inplace=True)

mb_01['Date'] = pd.to_datetime(mb_01['Date'])
mb_01.set_index('Date', inplace=True)


mb_01corr = mb_01.corr()

#사이즈 
fig, ax = plt.subplots(figsize=(15,12) )

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(mb_01corr , dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵
sns.heatmap(mb_01corr , 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()

# %%
# 선거기간 중 : "2007-04-23", "2007-12-20"

list_02 = []
for item_code in stock_dict.values():
    close_02 = fdr.DataReader(item_code, "2007-04-23", "2007-12-20")['Close']
    list_02.append(close_02)

mb_02 = pd.concat(list_02, axis=1)
mb_02.columns = stock_dict.keys()
mb_02.reset_index(inplace=True)

mb_02['Date'] = pd.to_datetime(mb_02['Date'])
mb_02.set_index('Date', inplace=True)

mb_02corr = mb_02.corr()

#사이즈 
fig, ax = plt.subplots( figsize=(15,12) )

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(mb_02corr , dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵
sns.heatmap(mb_02corr , 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()

# %%
# 당선이후 재임시절까지 (2007-12-21 ~ 2013-2-23)

list_03 = []
for item_code in stock_dict.values():
    close_03 = fdr.DataReader(item_code, "2007-12-21", "2013-02-23")['Close']
    list_03.append(close_03)

mb_03 = pd.concat(list_03, axis=1)
mb_03 .columns = stock_dict.keys()
mb_03 .reset_index(inplace=True)

mb_03 ['Date'] = pd.to_datetime(mb_03 ['Date'])
mb_03 .set_index('Date', inplace=True)

mb_03corr = mb_03 .corr()

#사이즈 
fig, ax = plt.subplots( figsize=(15,12) )

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(mb_03corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵
sns.heatmap(mb_03corr, 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()

# %%
# 당선이후 재임시절까지 (2007-12-21 ~ 2013-2-23)

list_03 = []
for item_code in stock_dict.values():
    close_03 = fdr.DataReader(item_code, "2007-12-21", "2013-02-23")['Close']
    list_03.append(close_03)

mb_03 = pd.concat(list_03, axis=1)
mb_03 .columns = stock_dict.keys()
mb_03 .reset_index(inplace=True)

mb_03 ['Date'] = pd.to_datetime(mb_03 ['Date'])
mb_03 .set_index('Date', inplace=True)

mb_03corr = mb_03 .corr()

fig = go.Figure(data=go.Heatmap(
          x = np.sort(xe),
          y = np.sort(ye),
          z = z,
          type = 'heatmap',
          colorscale = 'Viridis'))

fig.show()

# %%
#  2013 퇴임 이후 (2013-2~) # 안 씀

item_list = []
for item_code in stock_dict.values():
    close = fdr.DataReader(item_code, "2013-02-24", "2015-01-20")['Change']
    item_list.append(close)

df_mb_close_13 = pd.concat(item_list, axis=1)
df_mb_close_13.columns = stock_dict.keys()
df_mb_close_13.reset_index(inplace=True)

df_mb_close_13['Date'] = pd.to_datetime(df_mb_close_13['Date'])
df_mb_close_13.set_index('Date', inplace=True)
df_mb_close_13 = df_mb_close_13*100

corr13 = df_mb_close_13.corr()

#사이즈 
fig, ax = plt.subplots( figsize=(10,7) )

# 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
mask = np.zeros_like(corr13, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# 히트맵
sns.heatmap(corr13, 
            cmap = 'RdYlBu_r', 
            annot = True,   # 실제 값을 표시한다
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
           )  
plt.show()
