# %% [markdown]
# # Part1. 기본 세팅

# %% [markdown]
# ## 1. FDR, Pingouin install

# %%
pip install finance-datareader

# %% [markdown]
# ## 2. import library

# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
#number formatting
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # Part 2. 파일 세팅

# %% [markdown]
# ## 1. Stock Info

# %% [markdown]
# ### 1. 데이터 불러오기

# %%
# 17_이명박
stock_dict_mb = {
    '삼호개발': '010960',
    '이화공영': '001840',
    '홈센타': '060560',
    '특수건설': '026150',
    '동신건설': '025950',
    '모헨즈': '006920',
    }

item_list = []
for item_code in stock_dict_mb.values():
    change = fdr.DataReader(item_code, "2007-01-20", "2008-01-20")['Change']*100
    item_list.append(change)

df_mb_change_l = pd.concat(item_list, axis=1)
df_mb_change_l.columns = stock_dict_mb.keys()
df_mb_change_l.reset_index(inplace=True)

df_mb_change_l['Date'] = pd.to_datetime(df_mb_change_l['Date'])
df_mb_change_l.set_index('Date', inplace=True)
df_mb_change_l
# Out:
#              삼호개발   이화공영   홈센타   특수건설   동신건설   모헨즈
# Date
# 2007-01-22  10.18  -2.59 -3.21   6.59 -11.76  0.00
# 2007-01-23   2.11  -7.05  1.02  -1.66  -0.83 -4.97
# 2007-01-24  -7.74   0.00  1.01   4.73  -2.52 -3.64
# 2007-01-25  -7.60   2.43  2.00  -6.66   1.29  2.72
# 2007-01-26   4.09   1.40 -1.47  -3.15  -2.77 -2.18
# ...           ...    ...   ...    ...    ...   ...
# 2008-01-14  -3.31   1.71 -5.62  -4.27  -2.44 14.85
# 2008-01-15   1.46  -6.91 -3.19   2.59  15.00 14.99
# 2008-01-16 -11.21 -14.86 -9.81 -13.04 -14.86  5.21
# 2008-01-17  -3.25 -11.07 -2.75  -2.11  -5.11 14.97
# 2008-01-18  10.79  14.84 14.87  14.79  10.31 14.91
#
# [245 rows x 6 columns]

# %%
df_mb_change_l['평균수익률'] = (df_mb_change_l['삼호개발'] + df_mb_change_l['이화공영'] + df_mb_change_l['홈센타'] + df_mb_change_l['특수건설'] + df_mb_change_l['동신건설'] + df_mb_change_l['모헨즈'])/6
df_mb_change_l.head(5)
# Out:
#             삼호개발  이화공영   홈센타  특수건설   동신건설   모헨즈  평균수익률
# Date
# 2007-01-22 10.18 -2.59 -3.21  6.59 -11.76  0.00  -0.13
# 2007-01-23  2.11 -7.05  1.02 -1.66  -0.83 -4.97  -1.90
# 2007-01-24 -7.74  0.00  1.01  4.73  -2.52 -3.64  -1.36
# 2007-01-25 -7.60  2.43  2.00 -6.66   1.29  2.72  -0.97
# 2007-01-26  4.09  1.40 -1.47 -3.15  -2.77 -2.18  -0.68

# %%
# 17_정동영
stock_dict_dy = {
    '세명전기':'017510',
    '코마스인':'045390',
    '미주레일':'078940',
    '케이아이씨':'007460'}

item_list = []
for item_code in stock_dict_dy.values():
    change = fdr.DataReader(item_code, "2007-01-20", "2008-01-20")['Change']*100
    item_list.append(change)

df_dy_change_l = pd.concat(item_list, axis=1)
df_dy_change_l.columns = stock_dict_dy.keys()
df_dy_change_l.reset_index(inplace=True)

df_dy_change_l['Date'] = pd.to_datetime(df_dy_change_l['Date'])
df_dy_change_l.set_index('Date', inplace=True)

# %%
df_dy_change_l['평균수익률'] = (df_dy_change_l['세명전기'] + df_dy_change_l['코마스인'] + df_dy_change_l['미주레일'] + df_dy_change_l['케이아이씨'])/4
df_dy_change_l.head(5)
# Out:
#             세명전기  코마스인  미주레일  케이아이씨  평균수익률
# Date
# 2007-01-22 -1.51  0.00 -4.00   1.15  -1.09
# 2007-01-23  1.02 -1.85  2.61  -0.35   0.36
# 2007-01-24  1.52 -2.25 -2.03  -0.63  -0.85
# 2007-01-25  0.50  4.55  0.52   1.50   1.77
# 2007-01-26  0.50  4.65 -3.10  -0.35   0.42

# %%
# 18_박근혜
stock_dict_kh = {
    'EG':'037370',
    '비트컴퓨터':'032850',
    '대유플러스':'000300',
    '대유에이텍':'002880',
    '서한':'011370'}


item_list = []
for item_code in stock_dict_kh.values():
    change = fdr.DataReader(item_code, "2012-01-20", "2013-01-20")['Change']*100
    item_list.append(change)

df_kh_change_l = pd.concat(item_list, axis=1)
df_kh_change_l.columns = stock_dict_kh.keys()
df_kh_change_l.reset_index(inplace=True)

df_kh_change_l['Date'] = pd.to_datetime(df_kh_change_l['Date'])
df_kh_change_l.set_index('Date', inplace=True)

# %%
df_kh_change_l['평균수익률'] = (df_kh_change_l['EG'] + df_kh_change_l['비트컴퓨터'] + df_kh_change_l['대유플러스'] + df_kh_change_l['대유에이텍'] + df_kh_change_l['서한'])/5
df_kh_change_l.head(5)
# Out:
#               EG  비트컴퓨터  대유플러스  대유에이텍    서한  평균수익률
# Date
# 2012-01-20 -3.36  -5.82   1.88   0.82 -2.40  -1.77
# 2012-01-25  6.48  -0.57   9.13   4.17  2.05   4.25
# 2012-01-26 -2.08   3.90  -1.46   2.00  0.40   0.55
# 2012-01-27 -4.55  -5.70  -1.72  -2.56 -1.20  -3.14
# 2012-01-30 -5.71  -9.73  -4.08  -3.02 -0.81  -4.67

# %%
# 18_문재인
stock_dict_ji_18 = {
    '우리들휴브레인': '118000',
    '바른손': '018700',
    '조광페인트': '004910',
    '유성티엔에스': '024800',
    '신일산업': '002700'}


item_list = []
for item_code in stock_dict_ji_18.values():
    change = fdr.DataReader(item_code, "2012-01-20", "2013-01-20")['Change']*100
    item_list.append(change)

df_ji_18_change_l = pd.concat(item_list, axis=1)
df_ji_18_change_l.columns = stock_dict_ji_18.keys()
df_ji_18_change_l.reset_index(inplace=True)

df_ji_18_change_l['Date'] = pd.to_datetime(df_ji_18_change_l['Date'])
df_ji_18_change_l.set_index('Date', inplace=True)

# %%
df_ji_18_change_l['평균수익률'] = (df_ji_18_change_l['우리들휴브레인'] + df_ji_18_change_l['바른손'] + df_ji_18_change_l['조광페인트'] + df_ji_18_change_l['유성티엔에스'] + df_ji_18_change_l['신일산업'])/5
df_ji_18_change_l.head(5)
# Out:
#             우리들휴브레인   바른손  조광페인트  유성티엔에스  신일산업  평균수익률
# Date
# 2012-01-20     1.06  0.93  14.92    0.78 -1.32   3.27
# 2012-01-25     8.30 14.87  14.81   14.99 -1.12  10.37
# 2012-01-26    -3.01  8.62  14.84    2.18  3.85   5.29
# 2012-01-27     1.11 15.00   7.69    6.24  4.14   6.84
# 2012-01-30     3.47 14.96  15.00    3.23 -1.67   7.00

# %%
#19_문재인
stock_dict_ji_19 = {
    '우리들휴브레인': '118000',
    '바른손': '018700',
    '뉴보택': '060260',
    '고려산업': '002140',
    'DSR제강': '069730',
    'DSR': '155660'}


item_list = []
for item_code in stock_dict_ji_19.values():
    change = fdr.DataReader(item_code, "2016-06-10", "2017-06-10")['Change']*100
    item_list.append(change)

df_ji_19_change_l = pd.concat(item_list, axis=1)
df_ji_19_change_l.columns = stock_dict_ji_19.keys()
df_ji_19_change_l.reset_index(inplace=True)

df_ji_19_change_l['Date'] = pd.to_datetime(df_ji_19_change_l['Date'])
df_ji_19_change_l.set_index('Date', inplace=True)

# %%
df_ji_19_change_l['평균수익률'] = (df_ji_19_change_l['우리들휴브레인'] + df_ji_19_change_l['바른손'] + df_ji_19_change_l['뉴보택'] + df_ji_19_change_l['고려산업'] + df_ji_19_change_l['DSR제강'] + df_ji_19_change_l['DSR'])/6
df_ji_19_change_l.head(5)
# Out:
#             우리들휴브레인   바른손   뉴보택  고려산업  DSR제강   DSR  평균수익률
# Date
# 2016-06-10     2.53 -3.22 -3.25 -0.24  -1.00  2.07  -0.52
# 2016-06-13     0.31  2.81 -4.33 -2.93  -1.65 -2.35  -1.36
# 2016-06-14    -1.17  0.27  0.46  0.00  -3.47 -3.50  -1.24
# 2016-06-15    -0.87 -0.53  0.22 -0.25  -2.00  1.48  -0.33
# 2016-06-16    -2.37 -0.24 -5.61 -3.28  -0.14 -0.56  -2.03

# %%
#19_홍준표
stock_dict_jp = {
    '한국선재': '025550',
    '영화금속' : '012280',
    '동방선기' :'099410',
    '두올' : '016740',
    '세우글로벌': '013000'
}

item_list = []
for item_code in stock_dict_jp.values():
    change = fdr.DataReader(item_code, "2016-06-10", "2017-06-10")['Change']*100
    item_list.append(change)

df_jp_change_l = pd.concat(item_list, axis=1)
df_jp_change_l.columns = stock_dict_jp.keys()
df_jp_change_l.reset_index(inplace=True)

df_jp_change_l['Date'] = pd.to_datetime(df_jp_change_l['Date'])
df_jp_change_l.set_index('Date', inplace=True)

# %%
# df_jp_close_l['주가평균'] = (df_jp_close_l['한국선재'] + df_jp_close_l['영화금속'] + df_jp_close_l['동방선기'] + df_jp_close_l['두올'] + df_jp_close_l['세우글로벌'])/5
df_jp_change_l_one = df_jp_change_l.loc['2016-06-10':'2016-07-29']
df_jp_change_l_two = df_jp_change_l.loc['2016-07-29':]

# %%
df_jp_change_l_one['평균수익률'] = (df_jp_change_l_one['한국선재'] + df_jp_change_l_one['영화금속'] + df_jp_change_l_one['동방선기'] + df_jp_change_l_one['세우글로벌'])/4
df_jp_change_l_two['평균수익률'] = (df_jp_change_l_two['한국선재'] + df_jp_change_l_two['영화금속'] + df_jp_change_l_two['동방선기'] + df_jp_change_l_two['두올'] + df_jp_change_l_two['세우글로벌'])/5
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_jp_change_l = pd.concat([df_jp_change_l_one, df_jp_change_l_two], axis=0)
df_jp_change_l.head(10)
# Out:
#              한국선재   영화금속   동방선기  두올  세우글로벌  평균수익률
# Date
# 2016-06-10  -3.47  -3.42  -3.04 nan   0.60  -2.33
# 2016-06-13   0.21   6.04  -1.57 nan  23.54   7.05
# 2016-06-14  -1.33   2.95  -4.60 nan   8.86   1.47
# 2016-06-15  -6.33   0.95   0.56 nan   4.35  -0.12
# 2016-06-16  -7.53  -8.32 -15.22 nan -14.74 -11.45
# 2016-06-17   5.39  -6.19  -6.96 nan   6.02  -0.44
# 2016-06-20  -0.68   2.86  -4.56 nan  10.87   2.12
# 2016-06-21   2.06 -10.26  -8.82 nan  10.45  -1.64
# 2016-06-22 -12.44  15.71 -13.98 nan -29.92 -10.16
# 2016-06-23  -1.15 -11.32  -4.06 nan -26.58 -10.78

# %% [markdown]
# # 박스플롯

# %% [markdown]
# ## 17대

# %%
#이명박
x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before = df_mb_change_l.loc['2007-01-20':'2007-04-20', '평균수익률']
during = df_mb_change_l.loc['2007-04-21':'2007-12-20', '평균수익률']
after = df_mb_change_l.loc['2007-12-21':'2008-01-20', '평균수익률']

y_data = [before, during, after]
colors = ['gray', 'crimson', 'gray']

fig = go.Figure()

for xd, yd, cls in zip(x_data, y_data, colors):
        fig.add_trace(go.Box(
            y=yd,
            name=xd,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            # fillcolor=cls,
            marker = dict(color=cls, opacity=0.6),
            line_color=cls,
            marker_size=2,
            line_width=1)
        )

#여기서부터는 차트 형식 설정입니다. 
fig.update_xaxes(title_text="Date", title_font_size=12)
fig.update_yaxes(title_text="수익률", title_font_size=12, range=[-15,15])
fig.update_layout(title_text=f'<b> 17대_수익률 평균_이명박 <b>',
                    autosize=True,
                    hoverlabel_font_color='#FFFFFF',
                    plot_bgcolor="white",
                    paper_bgcolor="white",                  
                    # plot_bgcolor="#F5F4F4",
                    # paper_bgcolor="#F5F4F4",
                    title_font_size = 18,
                    font_color="#3F3F3F")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="751e832a-39f9-4387-8682-e9af70de37a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("751e832a-39f9-4387-8682-e9af70de37a9")) {
#                     Plotly.newPlot(
#                         '751e832a-39f9-4387-8682-e9af70de37a9',
# ...

# %%
#정동영
x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before_dy = df_dy_change_l.loc['2007-01-20':'2007-04-20', '평균수익률']
during_dy = df_dy_change_l.loc['2007-04-21':'2007-12-20', '평균수익률']
after_dy = df_dy_change_l.loc['2007-12-21':'2008-01-20', '평균수익률']

y_data = [before_dy, during_dy, after_dy]
colors = ['gray', 'crimson', 'gray']

fig_box_dy = go.Figure()

for xd, yd, cls in zip(x_data, y_data, colors):
        fig_box_dy.add_trace(go.Box(
            y=yd,
            name=xd,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            # fillcolor=cls,
            marker = dict(color=cls, opacity=0.6),
            line_color=cls,
            marker_size=2,
            line_width=1)
        )

#여기서부터는 차트 형식 설정입니다. 
fig_box_dy.update_xaxes(title_text="Date", title_font_size=12)
fig_box_dy.update_yaxes(title_text="수익률", title_font_size=12, range=[-15,15])
fig_box_dy.update_layout(title_text=f'<b> 17대_수익률 평균_정동영 <b>',
                    autosize=True,
                    hoverlabel_font_color='#FFFFFF',
                    plot_bgcolor="white",
                    paper_bgcolor="white",                  
                    # plot_bgcolor="#F5F4F4",
                    # paper_bgcolor="#F5F4F4",
                    title_font_size = 18,
                    font_color="#3F3F3F")
fig_box_dy.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b03db908-8c2c-4178-8551-bb8866bb7a8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b03db908-8c2c-4178-8551-bb8866bb7a8b")) {
#                     Plotly.newPlot(
#                         'b03db908-8c2c-4178-8551-bb8866bb7a8b',
# ...

# %% [markdown]
# ##18대

# %%
#박근혜
x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before_kh = df_kh_change_l.loc['2012-01-20':'2012-04-20', '평균수익률']
during_kh = df_kh_change_l.loc['2012-04-20':'2012-12-20', '평균수익률']
after_kh = df_kh_change_l.loc['2012-12-21':'2013-01-20', '평균수익률']

y_data = [before_kh, during_kh, after_kh]
colors = ['gray', 'crimson', 'gray']

fig_box_kh = go.Figure()

for xd, yd, cls in zip(x_data, y_data, colors):
        fig_box_kh.add_trace(go.Box(
            y=yd,
            name=xd,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            # fillcolor=cls,
            marker = dict(color=cls, opacity=0.6),
            line_color=cls,
            marker_size=2,
            line_width=1)
        )

#여기서부터는 차트 형식 설정입니다. 
fig_box_kh.update_xaxes(title_text="Date", title_font_size=12)
fig_box_kh.update_yaxes(title_text="수익률", title_font_size=12, range=[-15,15])
fig_box_kh.update_layout(title_text=f'<b> 18대_수익률 평균_박근혜 <b>',
                    autosize=True,
                    hoverlabel_font_color='#FFFFFF',
                    plot_bgcolor="white",
                    paper_bgcolor="white",                  
                    # plot_bgcolor="#F5F4F4",
                    # paper_bgcolor="#F5F4F4",
                    title_font_size = 18,
                    font_color="#3F3F3F")

fig_box_kh.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="376efc1e-18c6-4d00-b4ff-b128c1c5a4fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("376efc1e-18c6-4d00-b4ff-b128c1c5a4fe")) {
#                     Plotly.newPlot(
#                         '376efc1e-18c6-4d00-b4ff-b128c1c5a4fe',
# ...

# %%
#문재인
x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before_ji_18 = df_ji_18_change_l.loc['2012-01-20':'2012-04-20', '평균수익률']
during_ji_18 = df_ji_18_change_l.loc['2012-04-20':'2012-12-20', '평균수익률']
after_ji_18 = df_ji_18_change_l.loc['2012-12-21':'2013-01-20', '평균수익률']

y_data = [before_ji_18, during_ji_18, after_ji_18]
colors = ['gray', 'crimson', 'gray']

fig_box_ji_18 = go.Figure()

for xd, yd, cls in zip(x_data, y_data, colors):
        fig_box_ji_18.add_trace(go.Box(
            y=yd,
            name=xd,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            # fillcolor=cls,
            marker = dict(color=cls, opacity=0.6),
            line_color=cls,
            marker_size=2,
            line_width=1)
        )

#여기서부터는 차트 형식 설정입니다. 
fig_box_ji_18.update_xaxes(title_text="Date", title_font_size=12)
fig_box_ji_18.update_yaxes(title_text="수익률", title_font_size=12, range=[-15,15])
fig_box_ji_18.update_layout(title_text=f'<b> 18대_수익률 평균_문재인 <b>',
                    autosize=True,
                    hoverlabel_font_color='#FFFFFF',
                    plot_bgcolor="white",
                    paper_bgcolor="white",                  
                    # plot_bgcolor="#F5F4F4",
                    # paper_bgcolor="#F5F4F4",
                    title_font_size = 18,
                    font_color="#3F3F3F")

fig_box_ji_18.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="423d078b-afdf-4994-9f45-993e1f5c851e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("423d078b-afdf-4994-9f45-993e1f5c851e")) {
#                     Plotly.newPlot(
#                         '423d078b-afdf-4994-9f45-993e1f5c851e',
# ...

# %% [markdown]
# ## 19대

# %%
#문재인
x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before_ji_19 = df_ji_19_change_l.loc['2016-06-10 ':'2016-09-10', '평균수익률']
during_ji_19 = df_ji_19_change_l.loc['2016-09-11':'2017-5-10', '평균수익률']
after_ji_19 = df_ji_19_change_l.loc['2017-05-10':'2017-06-10', '평균수익률']

y_data = [before_ji_19, during_ji_19, after_ji_19]
colors = ['gray', 'crimson', 'gray']

fig_box_ji_19 = go.Figure()

for xd, yd, cls in zip(x_data, y_data, colors):
        fig_box_ji_19.add_trace(go.Box(
            y=yd,
            name=xd,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            # fillcolor=cls,
            marker = dict(color=cls, opacity=0.6),
            line_color=cls,
            marker_size=2,
            line_width=1)
        )

#여기서부터는 차트 형식 설정입니다. 
fig_box_ji_19.update_xaxes(title_text="Date", title_font_size=12)
fig_box_ji_19.update_yaxes(title_text="수익률", title_font_size=12, range=[-15,15])
fig_box_ji_19.update_layout(title_text=f'<b> 19대_수익률 평균_문재인 <b>',
                    autosize=True,
                    hoverlabel_font_color='#FFFFFF',
                    plot_bgcolor="white",
                    paper_bgcolor="white",                  
                    # plot_bgcolor="#F5F4F4",
                    # paper_bgcolor="#F5F4F4",
                    title_font_size = 18,
                    font_color="#3F3F3F")

fig_box_ji_19.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6c5cd5f3-2abd-4484-a3f8-b27f797c7914" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6c5cd5f3-2abd-4484-a3f8-b27f797c7914")) {
#                     Plotly.newPlot(
#                         '6c5cd5f3-2abd-4484-a3f8-b27f797c7914',
# ...

# %%
#홍준표
x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before_jp = df_jp_change_l.loc['2016-06-10 ':'2016-09-10', '평균수익률']
during_jp = df_jp_change_l.loc['2016-09-11':'2017-5-10', '평균수익률']
after_jp = df_jp_change_l.loc['2017-05-10':'2017-06-10', '평균수익률']

y_data = [before_jp, during_jp, after_jp]
colors = ['gray', 'crimson', 'gray']

fig_box_jp = go.Figure()

for xd, yd, cls in zip(x_data, y_data, colors):
        fig_box_jp.add_trace(go.Box(
            y=yd,
            name=xd,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            # fillcolor=cls,
            marker = dict(color=cls, opacity=0.6),
            line_color=cls,
            marker_size=2,
            line_width=1)
        )

#여기서부터는 차트 형식 설정입니다. 
fig_box_jp.update_xaxes(title_text="Date", title_font_size=12)
fig_box_jp.update_yaxes(title_text="수익률", title_font_size=12, range=[-15,15])
fig_box_jp.update_layout(title_text=f'<b> 19대_수익률 평균_홍준표 <b>',
                    autosize=True,
                    hoverlabel_font_color='#FFFFFF',
                    plot_bgcolor="white",
                    paper_bgcolor="white",                  
                    # plot_bgcolor="#F5F4F4",
                    # paper_bgcolor="#F5F4F4",
                    title_font_size = 18,
                    font_color="#3F3F3F")

fig_box_jp.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7a81aff4-69e7-447d-95a7-8118bceb10af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7a81aff4-69e7-447d-95a7-8118bceb10af")) {
#                     Plotly.newPlot(
#                         '7a81aff4-69e7-447d-95a7-8118bceb10af',
# ...

# %% [markdown]
# # EXPORT

# %%
#csv 출력_17_이명박
df_mb_close_l.to_csv('/content/drive/MyDrive/dait5_Final/Phase3/mb_average.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-4f00c6e386f8> in <module>()
#       1 #csv 출력_17_이명박
# ----> 2 df_mb_close_l.to_csv('/content/drive/MyDrive/dait5_Final/Phase3/mb_average.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/csvs.py in save(self)
#     188                 encoding=self.encoding,
#     189                 errors=self.errors,
# ...

# %%
#csv 출력_17_정동영
df_dy_close_l.to_csv('/content/drive/MyDrive/dait5_Final/Phase3/dy_average.csv')

# %%
#csv 출력_18_박근혜
df_kh_close_l.to_csv('/content/drive/MyDrive/dait5_Final/Phase3/kh_average.csv')

# %%
#csv 출력_18_문재인
df_ji_18_close_l.to_csv('/content/drive/MyDrive/dait5_Final/Phase3/ji_18_average.csv')

# %%
#csv 출력_19_문재인
df_ji_19_close_l.to_csv('/content/drive/MyDrive/dait5_Final/Phase3/ji_19_average.csv')

# %%
#csv 출력_19_홍준표
df_jp_close_l.to_csv('/content/drive/MyDrive/dait5_Final/Phase3/jp_average.csv')

# %%
# 17_이명박
stock_dict_mb = {
    '삼호개발': '010960',
    '이화공영': '001840',
    '홈센타': '060560',
    '특수건설': '026150',
    '동신건설': '025950',
    '모헨즈': '006920',
    }

item_list = []
for item_code in stock_dict_mb.values():
    close = fdr.DataReader(item_code, "2007-01-20", "2008-01-20")['Change']*100
    item_list.append(close)

df_mb_change_l = pd.concat(item_list, axis=1)
df_mb_change_l.columns = stock_dict_mb.keys()
df_mb_change_l.reset_index(inplace=True)

df_mb_change_l['Date'] = pd.to_datetime(df_mb_change_l['Date'])
df_mb_change_l.set_index('Date', inplace=True)
df_mb_change_l['평균'] = (df_mb_change_l['삼호개발'] + df_mb_change_l['이화공영'] + df_mb_change_l['홈센타'] + df_mb_change_l['특수건설'] + df_mb_change_l['동신건설'] + df_mb_change_l['모헨즈'])/6

# %%
import plotly.graph_objects as go

x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before = df_mb_change_l.loc['2007-01-20':'2007-04-20']
during = df_mb_change_l.loc['2007-04-21':'2007-12-20']
after = df_mb_change_l.loc['2007-12-21':'2008-01-20']

before.head(5)

# %%
import plotly.graph_objects as go

x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before = df_mb_change_l.loc['2007-01-20':'2007-04-20']
during = df_mb_change_l.loc['2007-04-21':'2007-12-20']
after = df_mb_change_l.loc['2007-12-21':'2008-01-20']

y_data = [before['평균'], during['평균'], after['평균']]
colors = ['rgba(93, 164, 214, 0.5)', 'rgba(255, 144, 14, 0.5)', 'rgba(44, 160, 101, 0.5)']

fig = go.Figure()

for xd, yd, cls in zip(x_data, y_data, colors):
        fig.add_trace(go.Box(
            y=yd,
            name=xd,
            boxpoints='all',
            jitter=0.5,
            whiskerwidth=0.2,
            fillcolor=cls,
            marker_size=2,
            line_width=1)
        )

#여기서부터는 차트 형식 설정입니다. 
fig.update_xaxes(title_text="Date", title_font_size=12)
fig.update_yaxes(title_text="수익률", title_font_size=12)
fig.update_layout(title_text=f'<b> 17대_수익률 평균_이명박 <b>',
                    autosize=True,
                    hoverlabel_font_color='#FFFFFF',
                    plot_bgcolor="#F5F4F4",
                    paper_bgcolor="#F5F4F4",
                    title_font_size = 18,
                    font_color="#3F3F3F")

fig.show()

# %%
import plotly.graph_objects as go

x_data = ['대선기간 전', '대선기간 중', '대선기간 후']


before = df_mb_change_l.loc['2007-01-20':'2007-04-20']
during = df_mb_change_l.loc['2007-04-21':'2007-12-20']
after = df_mb_change_l.loc['2007-12-21':'2008-01-20']

y_data = [before, during, after]

colors = ['rgba(93, 164, 214, 0.5)', 'rgba(255, 144, 14, 0.5)', 'rgba(44, 160, 101, 0.5)']


fig = go.Figure()
fig.add_trace(go.Box(y=y0, name='Sample A',
                marker_color = 'indianred'))
fig.add_trace(go.Box(y=y1, name = 'Sample B',
                marker_color = 'lightseagreen'))

fig.show()
